# %%
from data import morse_dictionary
LOGO = """
  __  __  ____  _____   _____ ______    _____ ____  _____  ______    _____ ______ _   _ ______ _____         _______ ____  _____  
 |  \/  |/ __ \|  __ \ / ____|  ____|  / ____/ __ \|  __ \|  ____|  / ____|  ____| \ | |  ____|  __ \     /\|__   __/ __ \|  __ \ 
 | \  / | |  | | |__) | (___ | |__    | |   | |  | | |  | | |__    | |  __| |__  |  \| | |__  | |__) |   /  \  | | | |  | | |__) |
 | |\/| | |  | |  _  / \___ \|  __|   | |   | |  | | |  | |  __|   | | |_ |  __| | . ` |  __| |  _  /   / /\ \ | | | |  | |  _  / 
 | |  | | |__| | | \ \ ____) | |____  | |___| |__| | |__| | |____  | |__| | |____| |\  | |____| | \ \  / ____ \| | | |__| | | \ \ 
 |_|  |_|\____/|_|  \_\_____/|______|  \_____\____/|_____/|______|  \_____|______|_| \_|______|_|  \_\/_/    \_\_|  \____/|_|  \_\
                                                                                                                                
"""

FINISH = """
   _____               _                                   
  / ____|             (_)                                  
 | (___   ___  ___ ___ _  ___  _ __     _____   _____ _ __ 
  \___ \ / _ \/ __/ __| |/ _ \| '_ \   / _ \ \ / / _ \ '__|
  ____) |  __/\__ \__ \ | (_) | | | | | (_) \ V /  __/ |   
 |_____/ \___||___/___/_|\___/|_| |_|  \___/ \_/ \___|_|   
"""

running = True
while running:
    print(LOGO)
    print("Enter a word or sentence to generate into morse code:\n")
    print("Unknown letters will be replaced with ?")
    text = input("Enter a word or sentence:")
    print(text)
    morse_list = [morse_dictionary.get(letter.lower(),'?') + " " for letter in text]
    morse = ''.join(str(x) for x in morse_list)
    print(morse)
    print("Would you like to generate another?\n")
    cont = input("Type Y to continue")
    if cont.lower != 'y' and cont.lower != 'yes':
        running = False
        print(FINISH)
# Out:
#   __  __  ____  _____   _____ ______    _____ ____  _____  ______    _____ ______ _   _ ______ _____         _______ ____  _____
#  |  \/  |/ __ \|  __ \ / ____|  ____|  / ____/ __ \|  __ \|  ____|  / ____|  ____| \ | |  ____|  __ \     /\|__   __/ __ \|  __ \
#  | \  / | |  | | |__) | (___ | |__    | |   | |  | | |  | | |__    | |  __| |__  |  \| | |__  | |__) |   /  \  | | | |  | | |__) |
#  | |\/| | |  | |  _  / \___ \|  __|   | |   | |  | | |  | |  __|   | | |_ |  __| | . ` |  __| |  _  /   / /\ \ | | | |  | |  _  /
#  | |  | | |__| | | \ \ ____) | |____  | |___| |__| | |__| | |____  | |__| | |____| |\  | |____| | \ \  / ____ \| | | |__| | | \ \
#  |_|  |_|\____/|_|  \_\_____/|______|  \_____\____/|_____/|______|  \_____|______|_| \_|______|_|  \_\/_/    \_\_|  \____/|_|  \_
#
# Enter a word or sentence to generate into morse code:
#
# Unknown letters will be replaced with ?
# Did this work?
# -.. .. -..   - .... .. ...   .-- --- .-. -.- ..--..
# ...

# %% [markdown]
# Reflection Thoughts:
#
# That was pretty easy to start with. A dictionary made sense to import. I'm glad I got a chance to try out list comprehension rather than tackling one character at a time. Some ASCII text art also makes it a little nicer to look at. The task was just to create a command line program so I think that's as complicated as it needs to be.
